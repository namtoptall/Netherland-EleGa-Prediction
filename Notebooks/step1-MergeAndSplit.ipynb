# %% [markdown]
# # Data merging and Cleaning
# ##### After briefly checking the dataset, I decided to merge the dataset by company in order to clean it since each company has their own value
# ### about the requirement dataset :
# - ```net_manager``` : code of regional network manager
# - ```Purchase_area```: code of the area where the energy is purchased
# - ```street```: Name of the street
# - ```zipcode_from``` and ```zipcode_to```: 2 columns for the range of zipcodes covered, 4 numbers and 2 letters
# - ```city```: Name of the city
# - ```num_connections```: Number of connections in the range of zipcodes
# - ```delivery_perc```: percentage of the net consumption of electricity or gas. The lower, the
# more energy was given back to the grid (for example if you have solar panels)
# - ```perc_of_active_connections```: Percentage of active connections in the zipcode range
# - ```type_of_connection```: principal type of connection in the zipcode range. For electricity
# is # fuses X # ampère. For gas is G4, G6, G10, G16, G25
# - ```type_conn_perc```: percentage of presence of the principal type of connection in the
# zipcode range
# - ```annual_consume```: Annual consume. Kwh for electricity, m3 for gas
# - ```annual_consume_lowtarif_perc```: Percentage of consume during the low tarif hours.
# From 10 p.m. to 7 a.m. and during weekends.
# - ```smartmeter_perc```: percentage of smartmeters in the zipcode ranges
#
# ### Summary of cleaning steps
# - Merge the data by companies.
# - re-split by type and year

# %%
import pandas as pd

# %%
# open the coteq company datasets
Ecoteq_2018 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Electricity/coteq_electricity_2018.csv')
Ecoteq_2019 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Electricity/coteq_electricity_2019.csv')
Ecoteq_2020 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Electricity/coteq_electricity_2020.csv')
Ecoteq_2018['Year'] = 2018
Ecoteq_2019['Year'] = 2019
Ecoteq_2020['Year'] = 2020
Ecoteq_2018['Type'] = 'Electricity'
Ecoteq_2019['Type'] = 'Electricity'
Ecoteq_2020['Type'] = 'Electricity'
# for Gas dataset
Gcoteq_2018 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Gas/coteq_gas_2018.csv')
Gcoteq_2019 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Gas/coteq_gas_2019.csv')
Gcoteq_2020 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Gas/coteq_gas_2020.csv')
Gcoteq_2018['Year'] = 2018
Gcoteq_2019['Year'] = 2019
Gcoteq_2020['Year'] = 2020
Gcoteq_2018['Type'] = 'Gas'
Gcoteq_2019['Type'] = 'Gas'
Gcoteq_2020['Type'] = 'Gas'

# do similar action with other 2 companies
Estedin_2018 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Electricity/stedin_electricity_2018.csv')
Estedin_2019 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Electricity/stedin_electricity_2019.csv')
Estedin_2020 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Electricity/stedin_electricity_2020.csv')
Estedin_2018['Year'] = 2018
Estedin_2019['Year'] = 2019
Estedin_2020['Year'] = 2020
Estedin_2018['Type'] = 'Electricity'
Estedin_2019['Type'] = 'Electricity'
Estedin_2020['Type'] = 'Electricity'
Gstedin_2018 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Gas/stedin_gas_2018.csv')
Gstedin_2019 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Gas/stedin_gas_2019.csv')
Gstedin_2020 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Gas/stedin_gas_2020.csv')
Gstedin_2018['Year'] = 2018
Gstedin_2019['Year'] = 2019
Gstedin_2020['Year'] = 2020
# add type
Gstedin_2018['Type'] = 'Gas'
Gstedin_2019['Type'] = 'Gas'
Gstedin_2020['Type'] = 'Gas'

# westland-infra dataset
EWlinfra_2018 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Electricity/westland-infra_electricity_2018.csv')
EWlinfra_2019 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Electricity/westland-infra_electricity_2019.csv')
EWlinfra_2020 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Electricity/westland-infra_electricity_2020.csv')
EWlinfra_2018['Year'] = 2018
EWlinfra_2019['Year'] = 2019
EWlinfra_2020['Year'] = 2020
EWlinfra_2018['Type'] = 'Electricity'
EWlinfra_2019['Type'] = 'Electricity'
EWlinfra_2020['Type'] = 'Electricity'
# open Gas dataset and add year,type column
GWlinfra_2018 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Gas/westland-infra_gas_2018.csv')
GWlinfra_2019 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Gas/westland-infra_gas_2019.csv')
GWlinfra_2020 = pd.read_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/EEET2574_Assignment2_data/Gas/westland-infra_gas_2020.csv')
GWlinfra_2018['Year'] = 2018
GWlinfra_2019['Year'] = 2019
GWlinfra_2020['Year'] = 2020
GWlinfra_2018['Type'] = 'Gas'
GWlinfra_2019['Type'] = 'Gas'
GWlinfra_2020['Type'] = 'Gas'

# %%
# merge dataset by company 
# the index for each dataset are repeadtedly, so ignore_index = True
Coteq_dataset = pd.concat([Ecoteq_2018,Ecoteq_2019,Ecoteq_2020, Gcoteq_2018,Gcoteq_2019,Gcoteq_2020], ignore_index=True)
Coteq_dataset = pd.DataFrame(Coteq_dataset)
Stedin = pd.concat([Estedin_2018,Estedin_2019,Estedin_2020, Gstedin_2018,Gstedin_2019,Gstedin_2020], ignore_index=True)
Stedin_dataset = pd.DataFrame(Stedin)
Wlinfra_dataset = pd.concat([EWlinfra_2018,EWlinfra_2019,EWlinfra_2020, GWlinfra_2018,GWlinfra_2019,GWlinfra_2020], ignore_index=True)
Wlinfra_dataset = pd.DataFrame(Wlinfra_dataset)

# %%
print("Coteq company dataset :\n", Coteq_dataset.isnull().sum())
print("Stedin company dataset :\n",Stedin_dataset.isnull().sum())
print("Westland company dataset :\n",Wlinfra_dataset.isnull().sum())
# Out:
# Coteq company dataset :
#  net_manager                     0
# purchase_area                   0
# street                          0
# zipcode_from                    1
# zipcode_to                      0
# city                            0
# num_connections                 0
# delivery_perc                   0
# perc_of_active_connections      0
# type_conn_perc                  0
# type_of_connection              0
# annual_consume                  0
# annual_consume_lowtarif_perc    0
# smartmeter_perc                 0
# Year                            0
# Type                            0
# dtype: int64
# Stedin company dataset :
#  net_manager                          0
# purchase_area                        1
# street                               0
# zipcode_from                         0
# zipcode_to                           0
# city                                 0
# num_connections                      0
# delivery_perc                        0
# perc_of_active_connections           0
# type_conn_perc                       0
# type_of_connection                   0
# annual_consume                       0
# annual_consume_lowtarif_perc         0
# smartmeter_perc                      0
# Year                                 0
# Type                                 0
# STANDAARDDEVIATIE               424848
# dtype: int64
# Westland company dataset :
#  net_manager                     0
# purchase_area                   0
# street                          0
# zipcode_from                    0
# zipcode_to                      0
# city                            0
# delivery_perc                   0
# perc_of_active_connections      0
# %Defintieve aansl (NRM)         0
# type_conn_perc                  0
# type_of_connection              0
# annual_consume                  0
# annual_consume_lowtarif_perc    0
# smartmeter_perc                 0
# num_connections                 0
# Year                            0
# Type                            0
# dtype: int64

# %%
# find where the value is null
Coteq_dataset[Coteq_dataset['zipcode_from'].isnull()]
# Out:
#                    net_manager                        purchase_area  \
# 21283  Cogas Infra & Beheer BV  GAS Gastransport Services (GASUNIE)
#
#             street zipcode_from zipcode_to                      city  \
# 21283  Sportstraat          NaN     7165BD  WESTERHAAR-VRIEZENV WIJK
#
#        num_connections  delivery_perc  perc_of_active_connections  \
# 21283               26          100.0                        58.0
#
#        type_conn_perc type_of_connection  annual_consume  \
# 21283              69                 G4            3038
#
#        annual_consume_lowtarif_perc  smartmeter_perc  Year Type
# 21283                           0.0             46.0  2020  Gas

# %%
Stedin_dataset[Stedin_dataset['purchase_area'].isnull()]
# Out:
#           net_manager purchase_area      street zipcode_from zipcode_to  \
# 297293  8716892000005           NaN  Groenelaan       3114CB     3114CB
#
#             city  num_connections  delivery_perc  perc_of_active_connections  \
# 297293  SCHIEDAM               20          100.0                         0.0
#
#         type_conn_perc type_of_connection  annual_consume  \
# 297293            75.0                 G4          1230.0
#
#         annual_consume_lowtarif_perc  smartmeter_perc  Year Type  \
# 297293                           0.0              0.0  2018  Gas
#
#        STANDAARDDEVIATIE
# 297293               NaN

# %%
# fill by unknown 
Coteq_dataset['zipcode_from'].fillna('unknown', inplace=True)
Stedin_dataset['purchase_area'].fillna('unknown', inplace=True)

# %%
Coteq_dataset = pd.DataFrame(Coteq_dataset)
Stedin_dataset = pd.DataFrame(Stedin)
Wlinfra_dataset = pd.DataFrame(Wlinfra_dataset)

# %%
# split the dataset by type
Coteq_electricity = Coteq_dataset[Coteq_dataset['Type'] == 'Electricity']
Coteq_gas = Coteq_dataset[Coteq_dataset['Type'] == 'Gas']
Stedin_electricity = Stedin_dataset[Stedin_dataset['Type'] == 'Electricity']
Stedin_gas = Stedin_dataset[Stedin_dataset['Type'] == 'Gas']
Wlinfra_electricity = Wlinfra_dataset[Wlinfra_dataset['Type'] == 'Electricity']
Wlinfra_gas = Wlinfra_dataset[Wlinfra_dataset['Type'] == 'Gas']
# merge the Electricity dataset
Electricity_dataset = pd.concat([Coteq_electricity,Stedin_electricity,Wlinfra_electricity], ignore_index=True)
# split train/test by year
train_E = Electricity_dataset[Electricity_dataset['Year'] != 2020]
test_E = Electricity_dataset[Electricity_dataset['Year'] == 2020]
# merge the Gas dataset
Gas_dataset = pd.concat([Coteq_gas,Stedin_gas,Wlinfra_gas], ignore_index=True)
# split train/test by year
train_G = Gas_dataset[Gas_dataset['Year'] != 2020]
test_G = Gas_dataset[Gas_dataset['Year'] == 2020]

# %%
# save to csv
train_E.to_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/As2-EEET574/Merged_dataset/Electricity/E-Train.csv', index=False)
test_E.to_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/As2-EEET574/Merged_dataset/Electricity/E-Test.csv', index=False)
train_G.to_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2//As2-EEET574/Merged_dataset/Gas/G-Train.csv', index=False)
test_G.to_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/As2-EEET574/Merged_dataset/Gas/G-Test.csv', index=False)
