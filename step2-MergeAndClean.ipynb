# %% [markdown]
# # Data merging and briefly cleaning
# ##### After briefly checking the dataset, I decided to merge the dataset by company in order to clean it since each company has their own value
# - In this notebook, I merge Electricity and gas dataset, briefly walkthrough each, modify the column datatype for suitable training variable
# - Then, I split the dataset again by year (for training purpose)
# - Overall, This notebook ONLY CHECK THE COLUMNS AND DATAYPE of the given dataset.
# ### about the requirement dataset :
# - ```net_manager``` : code of regional network manager
# - ```Purchase_area```: code of the area where the energy is purchased
# - ```street```: Name of the street
# - ```zipcode_from``` and ```zipcode_to```: 2 columns for the range of zipcodes covered, 4 numbers and 2 letters
# - ```city```: Name of the city
# - ```num_connections```: Number of connections in the range of zipcodes
# - ```delivery_perc```: percentage of the net consumption of electricity or gas. The lower, the
# more energy was given back to the grid (for example if you have solar panels)
# - ```perc_of_active_connections```: Percentage of active connections in the zipcode range
# - ```type_of_connection```: principal type of connection in the zipcode range. For electricity
# is # fuses X # ampère. For gas is G4, G6, G10, G16, G25
# - ```type_conn_perc```: percentage of presence of the principal type of connection in the
# zipcode range
# - ```annual_consume```: Annual consume. Kwh for electricity, m3 for gas
# - ```annual_consume_lowtarif_perc```: Percentage of consume during the low tarif hours.
# From 10 p.m. to 7 a.m. and during weekends.
# - ```smartmeter_perc```: percentage of smartmeters in the zipcode ranges

# %%
import pandas as pd

# %%
# open the coteq company datasets
Ecoteq_2018 = pd.read_csv('/coteq_electricity_2018.csv')
Ecoteq_2019 = pd.read_csv('/coteq_electricity_2019.csv')
Ecoteq_2020 = pd.read_csv('/coteq_electricity_2020.csv')
Ecoteq_2018['Year'] = 2018
Ecoteq_2019['Year'] = 2019
Ecoteq_2020['Year'] = 2020
Ecoteq_2018['Type'] = 'Electricity'
Ecoteq_2019['Type'] = 'Electricity'
Ecoteq_2020['Type'] = 'Electricity'
# for Gas dataset
Gcoteq_2018 = pd.read_csv('/coteq_gas_2018.csv')
Gcoteq_2019 = pd.read_csv('/coteq_gas_2019.csv')
Gcoteq_2020 = pd.read_csv('/coteq_gas_2020.csv')
Gcoteq_2018['Year'] = 2018
Gcoteq_2019['Year'] = 2019
Gcoteq_2020['Year'] = 2020
Gcoteq_2018['Type'] = 'Gas'
Gcoteq_2019['Type'] = 'Gas'
Gcoteq_2020['Type'] = 'Gas'

# do similar action with other 2 companies
Estedin_2018 = pd.read_csv('/asignment2/EEET2574_Assignment2_data/Electricity/stedin_electricity_2018.csv')
Estedin_2019 = pd.read_csv('/asignment2/EEET2574_Assignment2_data/Electricity/stedin_electricity_2019.csv')
Estedin_2020 = pd.read_csv('/asignment2/EEET2574_Assignment2_data/Electricity/stedin_electricity_2020.csv')
Estedin_2018['Year'] = 2018
Estedin_2019['Year'] = 2019
Estedin_2020['Year'] = 2020
Estedin_2018['Type'] = 'Electricity'
Estedin_2019['Type'] = 'Electricity'
Estedin_2020['Type'] = 'Electricity'
Gstedin_2018 = pd.read_csv('/BigData/asignment2/EEET2574_Assignment2_data/Gas/stedin_gas_2018.csv')
Gstedin_2019 = pd.read_csv('/BigData/asignment2/EEET2574_Assignment2_data/Gas/stedin_gas_2019.csv')
Gstedin_2020 = pd.read_csv('/BigData/asignment2/EEET2574_Assignment2_data/Gas/stedin_gas_2020.csv')
Gstedin_2018['Year'] = 2018
Gstedin_2019['Year'] = 2019
Gstedin_2020['Year'] = 2020
# add type
Gstedin_2018['Type'] = 'Gas'
Gstedin_2019['Type'] = 'Gas'
Gstedin_2020['Type'] = 'Gas'

# westland-infra dataset
EWlinfra_2018 = pd.read_csv('/BigData/asignment2/EEET2574_Assignment2_data/Electricity/westland-infra_electricity_2018.csv')
EWlinfra_2019 = pd.read_csv('/BigData/asignment2/EEET2574_Assignment2_data/Electricity/westland-infra_electricity_2019.csv')
EWlinfra_2020 = pd.read_csv('/BigData/asignment2/EEET2574_Assignment2_data/Electricity/westland-infra_electricity_2020.csv')
EWlinfra_2018['Year'] = 2018
EWlinfra_2019['Year'] = 2019
EWlinfra_2020['Year'] = 2020
EWlinfra_2018['Type'] = 'Electricity'
EWlinfra_2019['Type'] = 'Electricity'
EWlinfra_2020['Type'] = 'Electricity'
# open Gas dataset and add year,type column
GWlinfra_2018 = pd.read_csv('/BigData/asignment2/EEET2574_Assignment2_data/Gas/westland-infra_gas_2018.csv')
GWlinfra_2019 = pd.read_csv('/BigData/asignment2/EEET2574_Assignment2_data/Gas/westland-infra_gas_2019.csv')
GWlinfra_2020 = pd.read_csv('/BigData/asignment2/EEET2574_Assignment2_data/Gas/westland-infra_gas_2020.csv')
GWlinfra_2018['Year'] = 2018
GWlinfra_2019['Year'] = 2019
GWlinfra_2020['Year'] = 2020
GWlinfra_2018['Type'] = 'Gas'
GWlinfra_2019['Type'] = 'Gas'
GWlinfra_2020['Type'] = 'Gas'

# %%
# merge dataset by company 
# the index for each dataset are repeadtedly, so ignore_index = True
Coteq_dataset = pd.concat([Ecoteq_2018,Ecoteq_2019,Ecoteq_2020, Gcoteq_2018,Gcoteq_2019,Gcoteq_2020], ignore_index=True)
Stedin = pd.concat([Estedin_2018,Estedin_2019,Estedin_2020, Gstedin_2018,Gstedin_2019,Gstedin_2020], ignore_index=True)
Stedin_dataset = pd.DataFrame(Stedin)
Wlinfra_dataset = pd.concat([EWlinfra_2018,EWlinfra_2019,EWlinfra_2020, GWlinfra_2018,GWlinfra_2019,GWlinfra_2020], ignore_index=True)

# %% [markdown]
# ### First, briefly check the Coteq_dataset

# %%
Coteq_dataset.head()
# Out:
#           net_manager                          purchase_area         street  \
# 0  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.    Dorpsstraat
# 1  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.  De Stoevelaar
# 2  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.  De Stoevelaar
# 3  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.  De Stoevelaar
# 4  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.     Kerkstraat
#
#   zipcode_from zipcode_to   city  num_connections  delivery_perc  \
# 0       7468CP     7471AA  ENTER               19          89.47
# 1       7471AB     7471AB   GOOR               37         100.00
# 2       7471AC     7471AC   GOOR               16         100.00
# 3       7471AD     7471AE   GOOR               25          92.00
# 4       7471AG     7471AG   GOOR               14          85.71
#
#    perc_of_active_connections  type_conn_perc type_of_connection  \
# ...

# %%
Coteq_dataset.tail()
# Out:
#                    net_manager                        purchase_area  \
# 28169  Cogas Infra & Beheer BV  GAS Gastransport Services (GASUNIE)
# 28170  Cogas Infra & Beheer BV  GAS Gastransport Services (GASUNIE)
# 28171  Cogas Infra & Beheer BV  GAS Gastransport Services (GASUNIE)
# 28172  Cogas Infra & Beheer BV  GAS Gastransport Services (GASUNIE)
# 28173  Cogas Infra & Beheer BV  GAS Gastransport Services (GASUNIE)
#
#                 street zipcode_from zipcode_to         city  num_connections  \
# 28169      Allemansweg       7798CK     7798CM  COLLENDOORN               18
# 28170       Luggersweg       7798CN     7798CN  COLLENDOORN               11
# 28171        Middenweg       7798CP     7798CW  COLLENDOORN               28
# 28172  Wetterkoelenweg       7798CX     7925PP  COLLENDOORN               14
# 28173   Braambergerweg       7926TT     7926TT   KERKENVELD                5
#
#        delivery_perc  perc_of_active_connections  type_conn_perc  \
# ...

# %%
Coteq_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28174 entries, 0 to 28173
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   net_manager                   28174 non-null  object
#  1   purchase_area                 28174 non-null  object
#  2   street                        28174 non-null  object
#  3   zipcode_from                  28173 non-null  object
#  4   zipcode_to                    28174 non-null  object
#  5   city                          28174 non-null  object
#  6   num_connections               28174 non-null  int64
#  7   delivery_perc                 28174 non-null  float64
#  8   perc_of_active_connections    28174 non-null  float64
#  9   type_conn_perc                28174 non-null  int64
#  10  type_of_connection            28174 non-null  object
#  11  annual_consume                28174 non-null  int64
# ...

# %% [markdown]
# ### --> Observations:
# - considered net_manager, purchase_area, street and city are categorical column (we have to train by year and there are differences companies and purchase area)
# - Since zipcode_from and zipcode_to contains unique zipcode I will work with that later
# - One more categorical column is type_of_connection, check later

# %%
# a function to check datatype of categorical columns
def check_unique_values(dataframe, categorical_columns):
    unique_values_dict = {}
    for column in categorical_columns:
        unique_values = dataframe[column].unique().tolist()
        unique_values_dict[column] = unique_values
    return unique_values_dict
categorical_columns_to_check = ['net_manager', 'purchase_area', 'street', 'city']
unique_values_result = check_unique_values(Coteq_dataset, categorical_columns_to_check)

# Print the results
for column, values in unique_values_result.items():
    print(f"Unique values for column '{column}': {values}")
# Out:
# Unique values for column 'net_manager': ['Coteq Netbeheer BV', 'Cogas Infra & Beheer BV']
# Unique values for column 'purchase_area': ['Netbeheerder Centraal Overijssel B.V.', 'GAS Gastransport Services (GASUNIE)']
# ...

# %%
# check missing values
Coteq_dataset.isnull().sum()
# Out:
# net_manager                     0
# purchase_area                   0
# street                          0
# zipcode_from                    1
# zipcode_to                      0
# city                            0
# num_connections                 0
# delivery_perc                   0
# perc_of_active_connections      0
# type_conn_perc                  0
# type_of_connection              0
# annual_consume                  0
# annual_consume_lowtarif_perc    0
# smartmeter_perc                 0
# Year                            0
# Type                            0
# dtype: int64

# %% [markdown]
# - the zipcode will be transfered later, so replace NaN value by Unknown

# %%
Coteq_dataset['zipcode_from'].fillna('UNKNOWN', inplace=True)

# %% [markdown]
# - According to Noord-Brabant, The "s-" at the beginning of some Dutch city names is a contraction of the Dutch word "des" which means "the" in English. It is a remnant of older Dutch grammar and is used to indicate possession or association with a particular noble family or lord. In the case of 's-Hertogenbosch, it refers to the Duke of Brabant
# https://www.eur.nl/sites/corporate/files/Thesis_Straatnamen_Kooloos.pdf
# - However, '-' and " ' " should be replaced when it turns to feature extraction --> replace by whitespace

# %%
def checkExtraWhiteSpace(ColName):
    Variable = [] 
    for anwser in Coteq_dataset[ColName].unique():
        for Com_Val in str(anwser).split(";"):
            if (Com_Val in Variable): 
                break
            words = Com_Val.split(" ")
            if ("" in words):
                print("Column '{}', variable '{}' contains extra whitespace.".format(ColName, Com_Val)
                )
                Variable.append(Com_Val)
                break
for column in Coteq_dataset.columns:
    if (str(Coteq_dataset[column].dtypes) == "object"):
        checkExtraWhiteSpace(column) # no white space

# %%
# apply uppercase to all object columns since they are mostly unique
def uppercaseAllObjectColumns(dataframe):
    for column in dataframe.columns:
        if (str(dataframe[column].dtypes) == "object"):
            dataframe[column] = dataframe[column].str.upper()
            
uppercaseAllObjectColumns(Coteq_dataset)
Coteq_dataset.head()
# Out:
#           net_manager                          purchase_area         street  \
# 0  COTEQ NETBEHEER BV  NETBEHEERDER CENTRAAL OVERIJSSEL B.V.    DORPSSTRAAT
# 1  COTEQ NETBEHEER BV  NETBEHEERDER CENTRAAL OVERIJSSEL B.V.  DE STOEVELAAR
# 2  COTEQ NETBEHEER BV  NETBEHEERDER CENTRAAL OVERIJSSEL B.V.  DE STOEVELAAR
# 3  COTEQ NETBEHEER BV  NETBEHEERDER CENTRAAL OVERIJSSEL B.V.  DE STOEVELAAR
# 4  COTEQ NETBEHEER BV  NETBEHEERDER CENTRAAL OVERIJSSEL B.V.     KERKSTRAAT
#
#   zipcode_from zipcode_to   city  num_connections  delivery_perc  \
# 0       7468CP     7471AA  ENTER               19          89.47
# 1       7471AB     7471AB   GOOR               37         100.00
# 2       7471AC     7471AC   GOOR               16         100.00
# 3       7471AD     7471AE   GOOR               25          92.00
# 4       7471AG     7471AG   GOOR               14          85.71
#
#    perc_of_active_connections  type_conn_perc type_of_connection  \
# ...

# %% [markdown]
# ### Done. now let's walk through the Stedin dataset and apply same/suitable techniques

# %%
# Do similar steps with other 2 companies
Stedin_dataset.head()
# Out:
#      net_manager   purchase_area                   street zipcode_from  \
# 0  8716874000009  Stedin Utrecht  Gijsbrecht van Amstelln       1181EJ
# 1  8716874000009  Stedin Utrecht            Rembrandtlaan       1231AC
# 2  8716874000009  Stedin Utrecht            Rembrandtlaan       1231AD
# 3  8716874000009  Stedin Utrecht            Jan Steenlaan       1231AE
# 4  8716874000009  Stedin Utrecht      Pieter de Hooghlaan       1231AG
#
#   zipcode_to        city  num_connections  delivery_perc  \
# 0     1231AB  AMSTELVEEN               33          93.94
# 1     1231AC  LOOSDRECHT               17         100.00
# 2     1231AD  LOOSDRECHT               17         100.00
# 3     1231AE  LOOSDRECHT               20         100.00
# 4     1231AG  LOOSDRECHT               17          94.12
#
#    perc_of_active_connections  type_conn_perc type_of_connection  \
# 0                       90.91            76.0               3x25
# ...

# %%
Stedin_dataset.tail()
# Out:
#           net_manager purchase_area                    street zipcode_from  \
# 511181  8716892000005    NG Leerdam           Multatulistraat       4207SG
# 511182  8716892000005    NG Leerdam         Louis Couperushof       4207SH
# 511183  8716892000005    NG Leerdam                Oltmanshof       4207SJ
# 511184  8716892000005    NG Leerdam         Jacob van Looyhof       4207SK
# 511185  8716892000005    NG Leerdam  Aart van der Leeuwstraat       4207SL
#
#        zipcode_to       city  num_connections  delivery_perc  \
# 511181     4207SG  GORINCHEM               16          100.0
# 511182     4207SH  GORINCHEM               10          100.0
# 511183     4207SJ  GORINCHEM               10          100.0
# 511184     4207SK  GORINCHEM               10          100.0
# 511185     4207SL  GORINCHEM               16          100.0
#
#         perc_of_active_connections  type_conn_perc type_of_connection  \
# 511181                       100.0           100.0                G04
# ...

# %% [markdown]
# - the ```STANDAARDDEVIATIE``` column is not in the description --> remove

# %%
# remove STANDAARDDEVIATIE
Stedin_dataset.drop(columns=['STANDAARDDEVIATIE'], inplace=True)

# %%
Stedin_dataset['net_manager'].value_counts()
# Out:
# 8716892000005    258569
# 8716874000009    138395
# 8716886000004     37155
# 8716921000006     25348
# 8716925000002      9328
# 8716892750009      9243
# 8716892700004      9225
# 8716892740000      9052
# 8716892710003      7778
# 8716892720002      5046
# 8716946000005      2026
# 8716924000003        21
# Name: net_manager, dtype: int64

# %% [markdown]
# #### The id columns is currently id, we should change it into net_manager name for matching the given dataset
# ##### Based on information from netbeheer, those id stands for Stedin B.V company. -> Apply company name to the column

# %%
Stedin_dataset['net_manager'] = 'Stedin B.V.'

# %%
Stedin_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511186 entries, 0 to 511185
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   net_manager                   511186 non-null  object
#  1   purchase_area                 511185 non-null  object
#  2   street                        511186 non-null  object
#  3   zipcode_from                  511186 non-null  object
#  4   zipcode_to                    511186 non-null  object
#  5   city                          511186 non-null  object
#  6   num_connections               511186 non-null  int64
#  7   delivery_perc                 511186 non-null  float64
#  8   perc_of_active_connections    511186 non-null  float64
#  9   type_conn_perc                511186 non-null  float64
#  10  type_of_connection            511186 non-null  object
#  11  annual_consume                511186 non-null  float64
# ...

# %%
# a function to check datatype of categorical columns
def check_unique_values(dataframe, categorical_columns):
    unique_values_dict = {}
    for column in categorical_columns:
        unique_values = dataframe[column].unique().tolist()
        unique_values_dict[column] = unique_values
    
    return unique_values_dict

categorical_columns_to_check = ['net_manager', 'purchase_area', 'street', 'city']
unique_values_result = check_unique_values(Stedin_dataset, categorical_columns_to_check)

# Print the results
for column, values in unique_values_result.items():
    print(f"Unique values for column '{column}': {values}")
# Out:
# Unique values for column 'net_manager': ['Stedin B.V.']
# Unique values for column 'purchase_area': ['Stedin Utrecht', 'Stedin', 'Stedin Midden-Holland', 'Stedin Delfland', 'Stedin Schiedam', 'Stedin Elektriciteit Zuid-Kennemerland', 'Stedin Weert', 'Duivendrecht', 'Halfweg', 'Pseudo-GOS Amstelland', 'Pseudo-GOS Zeist', 'Pseudo Gos Houten ENBU', 'Ouderkerk ad Amstel', 'Pseudo Gos Veenendaal ENBU', 'Pseudo-GOS Rotterdam', 'Pseudo-GOS Midden Kennemerland', 'NG Gouda', 'NG Hoekse waard', 'NG Den Haag', 'NG Heemstede', 'Pseudo Gos Hoogland ENBU', 'Pseudo-GOS Zoetermeer', 'Schiedam Kethel', 'Pseudo-GOS Delft', 'Wildersekade', 'Pseudo-GOS Bleiswijk', 'NG Waddinxveen', 'NG Leerdam', 'NG Krimpen', 'Pseudo-GOS Dordrecht', nan, 'Pseudo-GOS Vlaardingen', 'Maassluis', 'Hoek van Holland', 'Oranjelaan', 'Moerseweg', 'Ruigendijk', 'NG Brielle', 'Achterweg', 'NG Noord-Oost Friesland', 'Graswalseweg', 'Pseudo-GOS Weert', 'Weert Trancheeweg', 'Ameland']
# ...

# %%
Stedin_dataset.isnull().sum()
# Out:
# net_manager                     0
# purchase_area                   1
# street                          0
# zipcode_from                    0
# zipcode_to                      0
# city                            0
# num_connections                 0
# delivery_perc                   0
# perc_of_active_connections      0
# type_conn_perc                  0
# type_of_connection              0
# annual_consume                  0
# annual_consume_lowtarif_perc    0
# smartmeter_perc                 0
# Year                            0
# Type                            0
# dtype: int64

# %%
# replace 'SâGRAVENHAGE' in city by 'S GRAVENHAGE
Stedin_dataset['city'] = Stedin_dataset['city'].replace('SâGRAVENHAGE','S GRAVENHAGE')

# %%
# one missing value in purchase_area. Let see where it is
Stedin_dataset[Stedin_dataset['purchase_area'].isnull()]
# Out:
#         net_manager purchase_area      street zipcode_from zipcode_to  \
# 297293  Stedin B.V.           NaN  Groenelaan       3114CB     3114CB
#
#             city  num_connections  delivery_perc  perc_of_active_connections  \
# 297293  SCHIEDAM               20          100.0                         0.0
#
#         type_conn_perc type_of_connection  annual_consume  \
# 297293            75.0                 G4          1230.0
#
#         annual_consume_lowtarif_perc  smartmeter_perc  Year Type
# 297293                           0.0              0.0  2018  Gas

# %%
Stedin_dataset['purchase_area'].fillna('UNKNOWN', inplace=True)

# %%
def checkExtraWhiteSpace(ColName):
    Variable = [] 
    for anwser in Stedin_dataset[ColName].unique():
        for Com_Val in str(anwser).split(";"):
            if (Com_Val in Variable): 
                break
            words = Com_Val.split(" ")
            if ("" in words):
                print("Column '{}', variable '{}' contains extra whitespace.".format(ColName, Com_Val)
                )
                Variable.append(Com_Val)
                break
for column in Stedin_dataset.columns:
    if (str(Stedin_dataset[column].dtypes) == "object"):
        checkExtraWhiteSpace(column)
# Out:
# Column 'street', variable 'Schoolstraat ' contains extra whitespace.
# Column 'street', variable 'Papaverweg ' contains extra whitespace.
# Column 'street', variable 'Brielsemeer ' contains extra whitespace.
# Column 'street', variable 'Baandershof ' contains extra whitespace.
# Column 'street', variable 'Enge IJsselweg ' contains extra whitespace.
# Column 'street', variable 'Japansetuinlaan ' contains extra whitespace.
# Column 'street', variable 'Valutaboulevard ' contains extra whitespace.
# Column 'street', variable 'Engelenweide ' contains extra whitespace.
# Column 'street', variable 'Hoekelumseboslaan ' contains extra whitespace.
# Column 'street', variable 'Zwijnsbergen ' contains extra whitespace.

# %%
# remove extra whitespace
Stedin_dataset['street'] = Stedin_dataset['street'].str.strip()

# %%
# apply uppercase to all object columns since they are mostly unique
def uppercaseAllObjectColumns(dataframe):
    for column in dataframe.columns:
        if (str(dataframe[column].dtypes) == "object"):
            dataframe[column] = dataframe[column].str.upper()
uppercaseAllObjectColumns(Coteq_dataset)

# %% [markdown]
# ### Finally, westland dataset

# %%
Wlinfra_dataset.head()
# Out:
#       net_manager       purchase_area       street zipcode_from zipcode_to  \
# 0  westland-infra  871687800090000015    OOSTEINDE       2291AA     2291AE
# 1  westland-infra  871687800090000015    WATERPARK       2291AK     2291AK
# 2  westland-infra  871687800090000015   AZALEAPARK       2291AL     2291AL
# 3  westland-infra  871687800090000015  DRUIVENLAAN       2291AN     2291AT
# 4  westland-infra  871687800090000015     KWAKLAAN       2291AV     2291AV
#
#          city  delivery_perc  perc_of_active_connections  \
# 0  WATERINGEN          89.66                      100.00
# 1  WATERINGEN          87.50                      100.00
# 2  WATERINGEN         100.00                      100.00
# 3  WATERINGEN          69.05                       97.62
# 4  WATERINGEN         100.00                      100.00
#
#    %Defintieve aansl (NRM)  type_conn_perc type_of_connection  annual_consume  \
# 0                      100              59               3x25            7029
# ...

# %%
Wlinfra_dataset.tail()
# Out:
#           net_manager       purchase_area               street zipcode_from  \
# 14406  westland-infra  871718518003006694         IN DE BALIJE       3155XA
# 14407  westland-infra  871718518003006694  KONINGIN JULIANAWEG       3155XB
# 14408  westland-infra  871718518003006694  KONINGIN JULIANAWEG       3155XC
# 14409  westland-infra  871718518003006694  KONINGIN JULIANAWEG       3155XE
# 14410  westland-infra  871718518003006694           MERESTEIJN       3155XJ
#
#       zipcode_to      city  delivery_perc  perc_of_active_connections  \
# 14406     3155XA  MAASLAND          100.0                       100.0
# 14407     3155XB  MAASLAND          100.0                       100.0
# 14408     3155XD  MAASLAND          100.0                       100.0
# 14409     3155XH  MAASLAND          100.0                       100.0
# 14410     3155XK  MAASLAND          100.0                       100.0
#
#        %Defintieve aansl (NRM)  type_conn_perc type_of_connection  \
# ...

# %%
Coteq_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28174 entries, 0 to 28173
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   net_manager                   28174 non-null  object
#  1   purchase_area                 28174 non-null  object
#  2   street                        28174 non-null  object
#  3   zipcode_from                  28174 non-null  object
#  4   zipcode_to                    28174 non-null  object
#  5   city                          28174 non-null  object
#  6   num_connections               28174 non-null  int64
#  7   delivery_perc                 28174 non-null  float64
#  8   perc_of_active_connections    28174 non-null  float64
#  9   type_conn_perc                28174 non-null  int64
#  10  type_of_connection            28174 non-null  object
#  11  annual_consume                28174 non-null  int64
# ...

# %%
def check_unique_values(dataframe, categorical_columns):
    unique_values_dict = {}
    for column in categorical_columns:
        unique_values = dataframe[column].unique().tolist()
        unique_values_dict[column] = unique_values
    return unique_values_dict
categorical_columns_to_check = ['net_manager', 'purchase_area', 'street', 'city']
unique_values_result = check_unique_values(Wlinfra_dataset, categorical_columns_to_check)

# Print the results
for column, values in unique_values_result.items():
    print(f"Unique values for column '{column}': {values}")
# Out:
# Unique values for column 'net_manager': ['westland-infra']
# Unique values for column 'purchase_area': [871687800090000015, 871718518003006694]
# ...

# %%
print(Wlinfra_dataset['purchase_area'].value_counts())
print(Wlinfra_dataset['net_manager'].value_counts())
# Out:
# 871687800090000015    7399
# 871718518003006694    7012
# Name: purchase_area, dtype: int64
# westland-infra    14411
# Name: net_manager, dtype: int64

# %%
# replace id by westland 
Wlinfra_dataset['net_manager'] = 'Westland Infra Netbeheer B.V.'

# %%
def checkExtraWhiteSpace(ColName):
    Variable = [] 
    for anwser in Wlinfra_dataset[ColName].unique():
        for Com_Val in str(anwser).split(";"):
            if (Com_Val in Variable): 
                break
            words = Com_Val.split(" ")
            if ("" in words):
                print("Column '{}', variable '{}' contains extra whitespace.".format(ColName, Com_Val)
                )
                Variable.append(Com_Val)
                break
for column in Wlinfra_dataset.columns:
    if (str(Wlinfra_dataset[column].dtypes) == "object"):
        checkExtraWhiteSpace(column) # no white space

# %%
# apply uppercase to all object columns since they are mostly unique
def uppercaseAllObjectColumns(dataframe):
    for column in dataframe.columns:
        if (str(dataframe[column].dtypes) == "object"):
            dataframe[column] = dataframe[column].str.upper()
uppercaseAllObjectColumns(Wlinfra_dataset)
Wlinfra_dataset.head()
# Out:
#                      net_manager       purchase_area       street  \
# 0  WESTLAND INFRA NETBEHEER B.V.  871687800090000015    OOSTEINDE
# 1  WESTLAND INFRA NETBEHEER B.V.  871687800090000015    WATERPARK
# 2  WESTLAND INFRA NETBEHEER B.V.  871687800090000015   AZALEAPARK
# 3  WESTLAND INFRA NETBEHEER B.V.  871687800090000015  DRUIVENLAAN
# 4  WESTLAND INFRA NETBEHEER B.V.  871687800090000015     KWAKLAAN
#
#   zipcode_from zipcode_to        city  delivery_perc  \
# 0       2291AA     2291AE  WATERINGEN          89.66
# 1       2291AK     2291AK  WATERINGEN          87.50
# 2       2291AL     2291AL  WATERINGEN         100.00
# 3       2291AN     2291AT  WATERINGEN          69.05
# 4       2291AV     2291AV  WATERINGEN         100.00
#
#    perc_of_active_connections  %Defintieve aansl (NRM)  type_conn_perc  \
# 0                      100.00                      100              59
# 1                      100.00                      100              63
# ...

# %%
# split the dataset by type
Coteq_electricity = Coteq_dataset[Coteq_dataset['Type'] == 'Electricity']
Coteq_gas = Coteq_dataset[Coteq_dataset['Type'] == 'Gas']
Stedin_electricity = Stedin_dataset[Stedin_dataset['Type'] == 'Electricity']
Stedin_gas = Stedin_dataset[Stedin_dataset['Type'] == 'Gas']
Wlinfra_electricity = Wlinfra_dataset[Wlinfra_dataset['Type'] == 'Electricity']
Wlinfra_gas = Wlinfra_dataset[Wlinfra_dataset['Type'] == 'Gas']
# merge the Electricity dataset
Electricity_dataset = pd.concat([Coteq_electricity,Stedin_electricity,Wlinfra_electricity], ignore_index=True)
# split train/test by year
train_E = Electricity_dataset[Electricity_dataset['Year'] != 2020]
test_E = Electricity_dataset[Electricity_dataset['Year'] == 2020]
# merge the Gas dataset
Gas_dataset = pd.concat([Coteq_gas,Stedin_gas,Wlinfra_gas], ignore_index=True)
# split train/test by year
train_G = Gas_dataset[Gas_dataset['Year'] != 2020]
test_G = Gas_dataset[Gas_dataset['Year'] == 2020]

# %%
# save to csv
train_E.to_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/Merged_dataset/Electricity/E-Train.csv', index=False)
test_E.to_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/Merged_dataset/Electricity/E-Test.csv', index=False)
train_G.to_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/Merged_dataset/Gas/G-Train.csv', index=False)
test_G.to_csv('C:/TaiLieuHocTap/RMIT/C-2023/BigData/asignment2/Merged_dataset/Gas/G-Test.csv', index=False)
